# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
data = {
    'House Size (sqft)': [1000, 1500, 1800, 2000, 2200, 2500],
    'Price (Rs)': [200000, 300000, 350000, 370000, 400000, 450000]
}

# %%
df = pd.DataFrame(data)

# %%
X = df[['House Size (sqft)']]  
y = df['Price (Rs)']

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
print("Intercept (b0):", model.intercept_)
print("Slope (b1):", model.coef_[0])
# Out:
# Intercept (b0): 46650.94339622633
# Slope (b1): 162.73584905660383

# %%
df['Predicted Price'] = model.predict(X)

# %%
plt.scatter(X, y, color='blue', label='Actual Price')
plt.plot(X, df['Predicted Price'], color='red', label='Regression Line')
plt.xlabel('House Size (sqft)')
plt.ylabel('Price (Rs)')
plt.title('House Size vs. Price')
plt.legend()
plt.grid(True)
plt.show()
